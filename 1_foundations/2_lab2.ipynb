# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key exists and begins sk-ant-
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key exists and begins gsk_

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine you are the chief policy advisor to a small island democracy of 1.2 million people facing projected permanent sea‑level rise that will render 30% of its land uninhabitable within 40 years, with GDP per capita ~$7,500, limited fiscal reserves, a polarized electorate, a rising nationalist party, and dependence on a single export industry; given a 10‑year planning window and the constraint that new public spending can average no more than 4% of GDP annually, produce a prioritized, phased (0–5 years, 5–15 years, 15–40 years) policy package that balances (a) protecting and relocating affected populations, (b) preserving economic stability and livelihoods, (c) upholding property rights and democratic legitimacy, (d) securing financing and international legal recognition for climate displacement, and (e) minimizing social unrest and demagogic exploitation — and for each policy item provide a succinct rationale, estimated costs and funding sources, measurable success indicators, main risks and mitigation strategies, and a communications plan to maintain public trust; finally, list the key assumptions you made and explain how your recommendations would change if any two of those assumptions were reversed (specify which).

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Here is a concise, prioritized policy package for a 1.2 million‑person, 7,500 USD per capita island democracy facing projected permanent sea‑level rise that would render about 30% of land uninhabitable within ~40 years. The plan is designed to fit a 10‑year planning window with a public‑spending constraint of no more than roughly 4% of GDP per year on new initiatives (GDP ~ USD 9 billion; cap ≈ USD 360 million per year on new public spending). It is phased to 0–5 years, 5–15 years, and 15–40 years, with options to scale up/down as fiscal space and international support evolve. Each policy item includes rationale, cost/funding sources, success indicators, risks/mitigations, and a communications plan. I also list key assumptions and how recommendations would change if two assumptions were reversed.
#
# Executive framing
# - Core tensions to balance: protect and relocate affected people; preserve livelihoods and economic stability; uphold property rights and democratic legitimacy; secure financing and recognition for climate displacement; and minimize social unrest and demagogic exploitation.
# - Core levers: robust governance and rights frameworks; protected relocation with voluntary, transparent processes; diversified economy and livelihoods; prudent risk financing (contingent credits, insurance, grants); and credible, inclusive communications that frame climate action as shared policy adaptation rather than political theater.
# - Financing approach: mix of domestic budget within the 4% cap, concessional MDB lending, climate finance grants, sovereign and diaspora bonds, PPPs, and private-sector investments in resilience and diversification. International recognition and climate displacement financing are pursued in parallel but remain contingent on good governance, baseline rights protections, and transparent processes.
#
# Phase 0–5 years (early action, priority items; cost envelope and funding within the annual 4% of GDP cap)
# Item 1. Climate Displacement Authority (CDA) and national legal framework for climate mobility
# - Rationale: Establish accountable governance, rights protections, and a clear legal basis for relocation, compensation, and cross‑border recognition if needed.
# - Estimated cost and funding: USD 30–40 million upfront; ~USD 5–10 million/year for ongoing operation; funding from national budget with possible donor grant mix.
# - Measurable success indicators: legal framework enacted; CDA staffed; documented rights protections; clear relocation procedures published; citizen comprehension surveys >70% trust in process.
# - Risks and mitigations: Governance capture; slow implementation. Mitigation: independent oversight, sunset clauses, mandatory quarterly reporting, citizen feedback loops.
# - Communications plan: Transparent timeline; stakeholder briefings with local leaders, civil society, and business groups; multilingual information campaigns; regular progress dashboards.
# - Cross-cutting rationale: Sets legitimacy and reduces risk of ad hoc relocations; builds trust essential for a polarized electorate.
#
# Item 2. Protection of vulnerable populations and early relocation planning
# - Rationale: Begin orderly, voluntary relocation planning (not forced) with safety margins and community consent.
# - Estimated cost and funding: USD 120–150 million over 0–5 years; donor grants and concessional loans alongside domestic funds.
# - Measurable success indicators: number of households with relocation plans; risk assessments completed for all high‑risk communities; relocation option surveys with uptake decisions by target groups.
# - Risks and mitigations: Resistance from affected communities; inadequate housing options. Mitigation: genuine consent, transparent compensation, rapid access to basic services in host areas.
# - Communications plan: Locally led town halls; visuals showing preferred settlement options; offset narratives that emphasize choice and rights protection.
#
# Item 3. Property rights, compensation framework, and land records modernization
# - Rationale: Provide equitable, legally robust mechanisms for valuation, buyouts/land readjustment, and post-relocation ownership; reduces post-relocation disputes.
# - Estimated cost and funding: USD 40–60 million; largely funded from national budget with MDB assistance.
# - Measurable success indicators: standardized valuation methods; transparent compensation timelines; no major post-relocation repossessions.
# - Risks/mitigations: Litigation risk; valuation disputes. Mitigation: independent valuation panels; tiered dispute resolution; clear statutory timelines.
# - Communications plan: Right-to-rights approach; publish valuation methodologies; offer free legal clinics.
#
# Item 4. Climate-resilient basic services and risk reduction in inhabited zones
# - Rationale: Protect critical services (water, sanitation, drainage, coastal drainage in remaining inhabited areas) while planning for relocation.
# - Estimated cost and funding: USD 60–90 million; combination of domestic funds, concessional loans, and climate grants.
# - Measurable success indicators: reliable service delivery in high-risk neighborhoods; reduced flood damages/waterlogging incidents; functional warning systems tested annually.
# - Risks/mitigations: Construction delays; cost overruns. Mitigation: modular, nature-based and grey/green hybrid solutions; strict project governance.
# - Communications plan: Timely service-impact communications; clearly link investments to continuity of daily life; beneficiary impact stories.
#
# Item 5. Economic diversification and resilience—diversify export base and livelihoods
# - Rationale: Reduce dependence on a single export sector, build resilience, and provide climate‑adjusted livelihoods (e.g., sustainable fisheries, agribusiness, aquaculture, eco-tourism, digital services).
# - Estimated cost and funding: USD 60–90 million; mix of public grants, concessional loans, and private‑sector co-funding; some programs funded via public‑private partnerships.
# - Measurable success indicators: number of diversified export clusters established; SME survival/growth rates; retraining program completion rates; private investment commitments.
# - Risks and mitigations: Sector underperformance; market access risks. Mitigation: phased pilots, risk-sharing instruments, export finance facilities.
#
# Item 6. Public communications and governance reforms to reduce unrest
# - Rationale: Counter demagogic exploitation with clear, transparent processes; build cross-partisan trust through participatory governance.
# - Estimated cost and funding: USD 15–25 million; funded from national budget with possible donor support for capacity building.
# - Measurable success indicators: public trust surveys; visible adherence to procedural standards; lower spikes in polarization-related incidents.
# - Risks/mitigations: Political pushback. Mitigation: independent oversight, nonpartisan messaging, and citizen assemblies for select topics.
#
# Item 7. Climate displacement financing mechanisms and international legal groundwork
# - Rationale: Prepare for financing needs and establish international recognition, liability concepts, and eligibility rules for climate displacement.
# - Estimated cost and funding: USD 20–35 million; early-stage funding from national budget with targeted grants; pursuit of concessional funds from MDBs and climate finance facilities.
# - Measurable success indicators: draft frameworks for grants/loans; letters of intent from at least two international partners; baseline insurance/contingent credit readiness.
# - Risks/mitigations: Slow negotiations; conditionality. Mitigation: parallel domestic readiness; clear milestones; transparent negotiations.
#
# Phase 5–15 years (mid-term actions; scaled investments as cap allows and/or new financing structures come online)
# Item 8. Large-scale relocation program (buyouts, housing, and social services in host communities)
# - Rationale: Clear, voluntary relocation with social support, housing, and integration services; minimize disruption and preserve livelihoods.
# - Estimated cost and funding: USD 300–650 million ( staged; public funds plus concessional loans and grants). Potential PPP contributions and land readjustment revenues.
# - Measurable success indicators: number of households relocated with settled housing; stable employment metrics in host communities; satisfaction with relocation outcomes.
# - Risks/mitigations: Social tension at host sites; over‑ or under‑compensation. Mitigation: robust impact assessments, grievance mechanisms, equitable compensation packages.
# - Communications plan: Ongoing transparency; town‑level briefings and success stories; third‑party oversight of relocations.
#
# Item 9. Expanded land readjustment and property rights enforcement
# - Rationale: Scale successful 0–5 outcomes to larger relocation areas; ensure post‑relocation property security.
# - Estimated cost and funding: USD 100–150 million.
# - Measurable success indicators: clear property titles issued; dispute rate below a defined threshold.
# - Risks/mitigations: Legal challenges; bureaucracy. Mitigation: streamlined processes and independent review bodies.
#
# Item 10. Climate-resilient infrastructure expansion and nature-based solutions
# - Rationale: Extend coastal protection and climate resilience to priority zones; increase natural buffering (mangroves, wetlands) and green infrastructure.
# - Estimated cost and funding: USD 150–250 million (phased); funded via climate finance, grants, and PPPs.
# - Measurable success indicators: area of coastline protected; reduction in coastal erosion incidents; biodiversity and ecosystem health metrics.
# - Risks/mitigations: Execution risk in remote areas. Mitigation: modular projects; community stewardship programs.
#
# Item 11. Deepening economic diversification and resilience (second-wave)
# - Rationale: Accelerate diversification, including renewables, tourism, fisheries, and digital services; improve job quality and wage resilience; align with relocation pathways where feasible.
# - Estimated cost and funding: USD 150–250 million (public + private co-investment; grants and concessional loans).
# - Measurable success indicators: new export clusters; job creation; investment commitments; workforce upskilling metrics.
# - Risks/mitigations: Global market volatility; tourism cycles. Mitigation: risk pooling, flexible investment incentives, and diversification across sectors.
#
# Phase 15–40 years (long-term actions; transformative but dependent on pathways, financing stability, and successful early phases)
# Item 12. Large-scale coastal protection, habitat restoration, and long-term relocation capacity (if needed)
# - Rationale: Build enduring infrastructure and settlement capacity to address ongoing sea-level rise and population movements; emphasize nature-based solutions where viable.
# - Estimated cost and funding: USD 500 million to several billion (variant by scenario and scope); financing from a mix of sovereign bonds, concessional loans, climate funds, and PPPs.
# - Measurable success indicators: protected land area; relocation capacity ready on standby; updated hazard maps and risk indices.
# - Risks/mitigations: Debt service burden; maintenance costs. Mitigation: staggered investment, performance-based contracts, and clear exit/scale-down triggers.
#
# Item 13. Education, workforce development, and long-term economic transformation
# - Rationale: Invest in human capital to adapt to new industries and climate realities; support lifelong learning and retraining.
# - Estimated cost and funding: USD 200–400 million; blended funding (domestic, grants, donor support, and private sector in-kind contributions).
# - Measurable success indicators: training completion rates; employment in diversified sectors; literacy and STEM metrics; private sector job creation.
# - Risks/mitigations: Mismatched skills; slow job absorption. Mitigation: employer-led curricula; apprenticeship programs; continuous evaluation.
#
# Item 14. International legal recognition, liability frameworks, and debt management
# - Rationale: Normalize climate mobility in international law, address liability expectations, and maintain fiscal sustainability.
# - Estimated cost and funding: USD 20–50 million; funded from national budget with targeted donor support.
# - Measurable success indicators: formal bilateral/multilateral commitments; legal instruments signed; debt sustainability indicators maintained.
# - Risks/mitigations: Negotiation deadlock; conditionalities. Mitigation: phased milestones; transparent reporting; independent facilitation.
#
# Key funding sources and sequencing
# - Domestic: within the 4% annual GDP cap, prioritized for governance, protection, early relocation planning, and essential protections.
# - Multilateral development banks (MDBs) and climate funds: concessional loans, grants, technical assistance; prioritizing rights protections, risk transfer, and resilience investments.
# - Private sector and PPPs: co-finance urban and coastal protection, relocation housing, and diversification projects; risk-sharing and performance-based contracts.
# - Bilateral donors and regional partners: grants for capacity building, legal modernization, and governance reforms.
# - Sovereign or diaspora bonds (longer horizon): stand-ready to fund longer-term adaptation and relocation phases if fiscal space allows and debt sustainability remains sound.
#
# Success indicators (high-level, to track across phases)
# - Protect and relocate: number of households relocated voluntarily with satisfactory housing and services; percentage of population with recognized rights in relocated zones.
# - Economic stability and livelihoods: diversification of export base; employment growth in diversified sectors; SME survival/growth; per‑capita income stability.
# - Property rights and legitimacy: timely issuance of titles/compensation; low dispute rates; transparent valuation standards.
# - Financing and recognition: commitments from international partners; legally binding frameworks for climate mobility; access to climate finance facilities.
# - Social stability: public trust in government, perceived fairness of processes, and reduced polarization indicators; credible, independent oversight outcomes.
#
# Risk management and communications
# - Core risks: political fragmentation, demagoguery, implementation delays, value disputes in compensation, and financing gaps.
# - Mitigations: inclusive, transparent processes; independent oversight; participatory decision-making for major relocations; clear grievance mechanisms; phased, data-driven milestones; robust risk finance (contingent credit lines, insurance, reserve funds).
# - Communications plan principles: clarity of purpose; consistent, nonpartisan messaging; early and continuous engagement with communities; visibility of benefits and tradeoffs; digestible public dashboards and progress reports; use of trusted local leaders and civil society partners to convey information.
#
# Key assumptions (and their role)
# - A1. Sea-level rise will render ~30% of land uninhabitable within ~40 years.
# - A2. GDP per capita remains around USD 7,500; population ~1.2 million; GDP around USD 9 billion.
# - A3. A 4% per-year cap on new public spending within the 10-year planning window is binding.
# - A4. International financing and formal recognition for climate displacement are available on reasonable terms.
# - A5. The island’s economy remains dependent on a single export sector, with limited fiscal reserves.
# - A6. A polarized electorate and a rising nationalist party persist, but governance capacity remains sufficient with proper safeguards.
# - A7. Climate adaptation/relocation costs are within the ranges assumed; technology and governance solutions will be implementable as planned.
#
# What would change if any two assumptions were reversed? Illustrative scenarios
# Scenario A (reverse 1): International financing and formal recognition for climate displacement are not available or are severely delayed (assumption A4 reversed)
# - What changes in policy emphasis:
#   - Greater emphasis on domestic financing and debt management (domestic capital markets, diaspora bonds, and public‑private partnerships with more favorable risk-sharing).
#   - Earlier development of a robust sovereign climate resilience fund and contingent credit lines with MDBs that do not rely on grant support.
#   - Phased relocation and protection projects would be re‑sequenced to align with domestic revenue growth and cheaper early-stage pilots rather than relying on external grants.
#   - Increased focus on governance reforms and transparency to maintain legitimacy without external endorsement.
# - Phase adjustments:
#   - 0–5 years: accelerate domestic governance reforms and rights protections; defer or adjust programs that would rely heavily on external grants; increase emphasis on locally sourced housing and services via PPPs or municipal bonds.
#   - 5–15 years: scale relocation gradually with more domestic funding and phased loans; implement revenue-generating resilience projects (e.g., green energy, climate insurance) to support debt service.
#   - 15–40 years: gradually build domestic resilience funding capacity and adapt to debt sustainability constraints; rely less on external financing for major long-term projects.
#
# Scenario B (reverse 2): The 4% GDP per‑year cap is lifted or widened (assumption A3 reversed)
# - What changes in policy emphasis:
#   - Earlier, larger, faster investments in relocation, coastal protection, and economic diversification could be pursued, given more fiscal space.
#   - Potential for more aggressive social protection expansions, education and training investments, and housing programs to accelerate stabilization and acceptance.
#   - Risk of near-term fiscal pressures: stronger budgeting discipline, sunset clauses, and performance-based triggers would be essential to avoid long-term debt sustainability problems.
# - Phase adjustments:
#   - 0–5 years: accelerate capital-intensive resilience and relocation pilots; fund green infrastructure and housing at a higher share of the plan; implement robust macro-fiscal guardrails (debt sustainability tests, contingent liabilities).
#   - 5–15 years: scale up relocation, large-scale coastal protection, and diversification financing with diversified funding sources (public, private, and donor).
#   - 15–40 years: implement large, long-run adaptation programs with a sustainable mix of debt and grants; ensure long-term debt service does not overwhelm budgets; institute formal climate risk transfer instruments.
#
# Why these plans remain credible and workable
# - They embed rights, legitimacy, and transparency at the core (CDA, property rights, independent oversight, participatory processes).
# - They recognize shared national interests: protecting citizens, maintaining livelihoods, and avoiding a “sunk-cost” trap by diversifying the economy and investing in human capital.
# - They are fiscally prudent within the stated cap and emphasize diversified financing (domestic, MDBs, grants, PPPs) so that no single funding source becomes a bottleneck.
# - They address social stability by tying relocation to consent, compensation, and clear, widely communicated benefits, reducing risks of demagogic exploitation.
#
# Key assumptions recap
# - Sea-level rise impact, land loss, and timing align with projections.
# - Economic configuration (GDP, population) remains within expected ranges.
# - Fiscal constraint (4% cap) holds in the planning window (0–10 years).
# - International financing and recognition for climate displacement are feasible.
# - The political environment remains governable with credible institutions and robust citizen engagement.
#
# If you want, I can tailor the cost ranges to more exact budget numbers for your country’s current fiscal data, or prepare a one-page executive summary for political leaders or a cabinet briefing slide deck.

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
